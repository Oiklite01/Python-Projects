# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
coco=pd.read_csv("flavors_of_cocoa.csv" , index_col=0,na_values=["??"])
missing=coco.isna().any(axis=0)
missing
# Out:
# Company             False
# Bean Origin         False
# Review Date          True
# Cocoa Percent       False
# Company Location    False
# Rating              False
# dtype: bool

# %%
d=pd.crosstab(index=coco['Company Location'],columns='count')
d=pd.DataFrame(d.sort_values('count',ascending=False).head(10))
d.plot(kind='bar',rot=0)
# Out:
# <Axes: xlabel='Company Location'>

# %%
coco.info()
coco.head()
max(coco['Rating'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1795 entries, 1 to 1795
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1795 non-null   object
#  1   Bean Origin       1795 non-null   object
#  2   Review Date       1791 non-null   float64
#  3   Cocoa Percent     1795 non-null   object
#  4   Company Location  1795 non-null   object
#  5   Rating            1795 non-null   float64
# dtypes: float64(2), object(4)
# memory usage: 98.2+ KB
# 5.0

# %%
type(np.nan)
# Out:
# float
