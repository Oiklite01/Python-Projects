# %%
import pandas
import matplotlib 
df=pandas.read_csv('dataset.csv',usecols=lambda x:x not in ['society','balcony'])
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size total_sqft  bath   price
# 0          2 BHK       1056   2.0   39.07
# 1      4 Bedroom       2600   5.0  120.00
# ...

# %%
df.dropna()
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size total_sqft  bath   price
# 0          2 BHK       1056   2.0   39.07
# 1      4 Bedroom       2600   5.0  120.00
# ...

# %%
df=df.iloc[:100]
df.at[56,'bath']=2
df.at[81,'bath']=4
df.isna().sum()
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# total_sqft      0
# bath            0
# price           0
# dtype: int64

# %%
df.loc[df.bath.isna()]
# Out:
# Empty DataFrame
# Columns: [area_type, availability, location, size, total_sqft, bath, price]
# Index: []

# %%
df.plot.bar(y='price', figsize=(5, 5))
df.plot.line(y='price', figsize=(5, 5))
df.plot.pie(y='price', figsize=(5, 5))
# Out:
# <Axes: ylabel='price'>
